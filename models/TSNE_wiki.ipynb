# %%
import pickle
import os.path
from nltk.corpus import stopwords
import sys
from gensim.models.doc2vec import TaggedDocument
from gensim import utils
from gensim.models import Doc2Vec
from sklearn.manifold import TSNE
import bokeh.plotting as bp
import numpy as np
from gensim.models import Word2Vec
from sklearn.decomposition import TruncatedSVD
from bokeh.models import HoverTool, BoxSelectTool
from bokeh.plotting import figure, show, output_notebook

model = Word2Vec.load("en_1000_no_stem2/en.model")
word_vectors = model.syn0
w2v_norm = word_vectors / np.linalg.norm(word_vectors)
word_map = dict(zip(model.index2word, w2v_norm))
rand_pick = np.random.choice(w2v_norm.shape[0], 10000, replace=False)
print(rand_pick)
rand_vecs = w2v_norm[rand_pick,:]
print("Finsihed creating word map")
tsne_model = TSNE(n_components=2, verbose=1, random_state=0)
tsne_d2v = tsne_model.fit_transform(rand_vecs)
print("Finished model Fitting with TSNE")
# Out:
# [1050707  533228  673240 ...,  756268  675554  897855]
# Finsihed creating word map
# [t-SNE] Computing pairwise distances...
# [t-SNE] Computed conditional probabilities for sample 1000 / 10000
# [t-SNE] Computed conditional probabilities for sample 2000 / 10000
# [t-SNE] Computed conditional probabilities for sample 3000 / 10000
# [t-SNE] Computed conditional probabilities for sample 4000 / 10000
# [t-SNE] Computed conditional probabilities for sample 5000 / 10000
# [t-SNE] Computed conditional probabilities for sample 6000 / 10000
# [t-SNE] Computed conditional probabilities for sample 7000 / 10000
# [t-SNE] Computed conditional probabilities for sample 8000 / 10000
# [t-SNE] Computed conditional probabilities for sample 9000 / 10000
# [t-SNE] Computed conditional probabilities for sample 10000 / 10000
# [t-SNE] Mean sigma: 0.000278
# [t-SNE] Error after 100 iterations with early exaggeration: 32.960167
# [t-SNE] Error after 200 iterations: 4.810977
# Finished model Fitting with TSNE
# Using gpu device 0: Graphics Device

# %%
output_notebook()
import pdb

print(rand_pick)
bag_of_words = []
for item in rand_pick:
    bag_of_words.append(model.index2word[item])
    
plot_d2v = bp.figure(plot_width=1000, plot_height=800, title="Middle East tweets (doc2vec)",
    tools="pan,wheel_zoom,box_zoom,reset,hover,previewsave",
    x_axis_type=None, y_axis_type=None, min_border=1)
print("Finished Created Figure")
plot_d2v.scatter(x=tsne_d2v[:,0], y=tsne_d2v[:,1],
                    source=bp.ColumnDataSource({
                        "tweet": bag_of_words[:10000],
                    }))
print("Plotting")
hover = plot_d2v.select(dict(type=HoverTool))
hover.tooltips={"word": "@tweet "}
show(plot_d2v)
print("Finished Plotting")
# Out:
#     <script type="text/javascript">
#
#       (function(global) {
#         function now() {
#           return new Date();
#         }
#
#         if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#           window._bokeh_onload_callbacks = [];
#         }
#
#         function run_callbacks() {
#           window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#           delete window._bokeh_onload_callbacks
#           console.info("Bokeh: all callbacks have finished");
#         }
#
#         function load_libs(js_urls, callback) {
#           window._bokeh_onload_callbacks.push(callback);
#           if (window._bokeh_is_loading > 0) {
#             console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#             return null;
#           }
#           if (js_urls == null || js_urls.length === 0) {
#             run_callbacks();
#             return null;
#           }
#           console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#           window._bokeh_is_loading = js_urls.length;
#           for (var i = 0; i < js_urls.length; i++) {
#             var url = js_urls[i];
#             var s = document.createElement('script');
#             s.src = url;
#             s.async = false;
#             s.onreadystatechange = s.onload = function() {
#               window._bokeh_is_loading--;
#               if (window._bokeh_is_loading === 0) {
#                 console.log("Bokeh: all BokehJS libraries loaded");
#                 run_callbacks()
#               }
#             };
#             s.onerror = function() {
#               console.warn("failed to load library " + url);
#             };
#             console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#             document.getElementsByTagName("head")[0].appendChild(s);
#           }
#         };var js_urls = ['https://cdn.pydata.org/bokeh/release/bokeh-0.11.0.min.js', 'https://cdn.pydata.org/bokeh/release/bokeh-widgets-0.11.0.min.js', 'https://cdn.pydata.org/bokeh/release/bokeh-compiler-0.11.0.min.js'];
#
#         var inline_js = [
#           function(Bokeh) {
#             Bokeh.set_log_level("info");
#           },
#           function(Bokeh) {
#             console.log("Bokeh: injecting CSS: https://cdn.pydata.org/bokeh/release/bokeh-0.11.0.min.css");
#             Bokeh.embed.inject_css("https://cdn.pydata.org/bokeh/release/bokeh-0.11.0.min.css");
#             console.log("Bokeh: injecting CSS: https://cdn.pydata.org/bokeh/release/bokeh-widgets-0.11.0.min.css");
#             Bokeh.embed.inject_css("https://cdn.pydata.org/bokeh/release/bokeh-widgets-0.11.0.min.css");
#           }
#         ];
#
#         function run_inline_js() {
#           for (var i = 0; i < inline_js.length; i++) {
#             inline_js[i](window.Bokeh);
#           }
#         }
#
#         if (window._bokeh_is_loading === 0) {
#           console.log("Bokeh: BokehJS loaded, going straight to plotting");
#           run_inline_js();
#         } else {
#           load_libs(js_urls, function() {
#             console.log("Bokeh: BokehJS plotting callback run at", now());
#             run_inline_js();
#           });
#         }
#       }(this));
#     </script>
#     <div>
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span>BokehJS successfully loaded.</span>
#     </div>
# [1050707  533228  673240 ...,  756268  675554  897855]
# Finished Created Figure
# Plotting
#     <div class="plotdiv" id="83feaad1-45ad-41bb-8741-3f20059c1656"></div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("83feaad1-45ad-41bb-8741-3f20059c1656");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '83feaad1-45ad-41bb-8741-3f20059c1656' but no matching script tag was found. ")
#       return false;
#     }var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"b71ee699-1cf3-4f96-adf7-cdfc0e9bc91f": {"version": "0.11.0", "roots": {"root_ids": ["f7c6ece0-2b64-4b68-9cf4-2e6ad4ad925f"], "references": [{"attributes": {"callback": null, "column_names": ["tweet", "y", "x"], "data": {"y": [5.284081359883797, -3.681223619165102, 1.7416385405745118, -0.8419658293696222, -4.453827814003191, 5.938394294114724, -0.9941750456561734, 4.215540087917276, 0.3130424472162564, -5.7519642825576955, -6.158224128809142, -4.095560324544272, -0.5196392830495157, 3.529098192833663, 5.953261912638924, 4.78717393128518, -2.0112826677155895, 7.718922358682309, -3.519062527656476, 5.027852354069584, 1.5706437672057318, 4.958746548446397, -0.3519897921527345, -3.525362562014915, -2.0236824693335627, -1.3596038335605745, 7.969738306636761, -2.0804271455718983, 0.18633283935207648, -3.038761768135194, 0.10812917004406913, 2.404917600141167, -2.1728875191588557, 5.940463006055964, -3.9879706692202337, -0.297187660087648, -4.5682323691178786, 1.4389966764367097, -6.725500716337818, 1.6339421824110396, -0.6270130266862258, 1.7757748296427143, -6.684864674537874, -1.7503232224676966, 8.00093018652655, -1.4176950286737788, -5.911081982718012, -0.6536806820533893, -3.471851569087441, -0.3850333910102958, -0.4157238314835584, -3.0403091697487046, 2.437657527141516, -2.4025590514472195, 0.5231318846682159, -4.299096493814433, 0.8319772453459671, 8.010042523971531, -5.745292057722013, 3.2550490359866204, 0.6930152409173468, 6.867702014258707, 4.517978291015789, 0.86557334661919, 7.30796295978309, -0.5148467314416073, 3.0532086265029457, -4.004276722398381, 8.214932172706503, -1.1750864762025879, -5.271291727440361, 1.6836206133679363, 8.061217411203218, 2.028518028870351, -6.27473225691645, 0.8306534404510721, 0.5208742654185459, -5.299631663830181, -1.6239115243296531, -0.25010586420543496, 6.863793596927686, 4.333645501405014, 2.5812627985654735, 5.4442371897599955, -2.0225696879465325, 8.15962500312887, 4.564860192869036, 4.798251750111091, 4.775466260259177, -2.5558548100106817, -2.199196231472816, -1.1121666778076034, -0.926778576201046, 6.8545843660965335, -0.5253263655627538, -3.0567479872485883, 8.113807662396454, -2.6618777104015514, -0.8303676700774951, 5.008862179541827, -0.9070266576269157, -0.39476113271876806, 0.7796392200645593, -3.787947597041499, -0.8653161206261927, -0.8508550808459991, 0.317067209398647, -2.086325898951954, 4.464199460630978, -2.8864869032114893, -2.2097476053756155, -2.0052623734100203, 3.9213804240510006, -0.2730088861492351, 2.6795927573624296, 5.773122718622931, 4.6080374456345385, -5.5046205542790005, 2.228424641968267, -2.5252907337501416, -2.7634422965519443, 1.8263906874556854, 5.050960528446023, 4.444491301324309, -1.2016340056231691, -2.839803625996793, -6.16107971458104, 6.394890201721693, 3.812736562351674, -0.8814943187712105, -4.0317291557068105, 0.8659711559472191, -0.8888213696303452, -0.9683690182946467, -0.624100635773701, -1.8932515979548206, 1.0805751732281146, -0.08594243490170121, 4.263150739651569, 5.475119921304841, -1.5040988022088295, 1.2508382314897486, 1.9798608836709366, 1.8376864217430302, -0.23444328624249877, 3.681117617688151, -3.2550246714956548, 1.5521692878884232, -0.17953213366801934, 2.1919861579043296, -4.970312503022966, -5.598930509041363, 1.709210141934588, -1.947877691935536, 1.6690999339984876, -3.201863050197508, -3.19174565324427, -5.666315463919473, 3.8454082577185336, -3.840158932285616, 0.29229478778020096, -2.410390244654374, 5.680420675313064, 5.271042268198074, 0.4559286857148852, 7.9310453082284775, -3.799826393517124, -1.097040955924087, 8.050450271663266, 4.694952155668191, -0.3892262961415217, -3.81082030994471, 0.7779930064397012, 2.0096881422837827, -0.17259351294093792, -4.158032879477764, -1.2660366841690063, 2.421494624026064, -4.021197300921553, -5.567569977857741, 1.5662872805586139, 1.3856633168317118, -2.8431383541125452, -3.0843568420863963, 0.3683040753319115, 4.897303221030083, -6.50078959153 ...
# Finished Plotting

# %%
model = Word2Vec.load("wiki_model/wiki.en.word2vec.model")
word_vectors = model.syn0
w2v_norm = word_vectors / np.linalg.norm(word_vectors)
word_map = dict(zip(model.index2word, w2v_norm))
rand_vecs = w2v_norm[np.random.choice(w2v_norm.shape[0], 10000, replace=False),:]
'''
words = []
for j in xrange(0,len(rand_vecs)):
    for i in xrange(0,len(word_map.values())):
        if(np.all(word_map.values()[i] == rand_vecs[j])):
            words.append(word_map.keys()[i])
'''
print("Finsihed creating word map")
tsne_model = TSNE(n_components=2, verbose=1, random_state=0)
tsne_d2v = tsne_model.fit_transform(rand_vecs)
print("Finished model Fitting with TSNE")
# Out:
# Finsihed creating word map
# [t-SNE] Computing pairwise distances...
# [t-SNE] Computed conditional probabilities for sample 1000 / 10000
# [t-SNE] Computed conditional probabilities for sample 2000 / 10000
# [t-SNE] Computed conditional probabilities for sample 3000 / 10000
# [t-SNE] Computed conditional probabilities for sample 4000 / 10000
# [t-SNE] Computed conditional probabilities for sample 5000 / 10000
# [t-SNE] Computed conditional probabilities for sample 6000 / 10000
# [t-SNE] Computed conditional probabilities for sample 7000 / 10000
# [t-SNE] Computed conditional probabilities for sample 8000 / 10000
# [t-SNE] Computed conditional probabilities for sample 9000 / 10000
# [t-SNE] Computed conditional probabilities for sample 10000 / 10000
# [t-SNE] Mean sigma: 0.000219
# [t-SNE] Error after 100 iterations with early exaggeration: 22.552569
# [t-SNE] Error after 207 iterations: 3.094182
# Finished model Fitting with TSNE

# %%
output_notebook()
bag_of_words = []
for item in rand_pick:
    bag_of_words.append(model.index2word[item])
    
plot_d2v = bp.figure(plot_width=1000, plot_height=800, title="Middle East tweets (doc2vec)",
    tools="pan,wheel_zoom,box_zoom,reset,hover,previewsave",
    x_axis_type=None, y_axis_type=None, min_border=1)
print("Finished Created Figure")
plot_d2v.scatter(x=tsne_d2v[:,0], y=tsne_d2v[:,1],
                    source=bp.ColumnDataSource({
                        "tweet": bag_of_words[:10000],
                    }))
print("Plotting")
hover = plot_d2v.select(dict(type=HoverTool))
hover.tooltips={"word": "@tweet "}
show(plot_d2v)
print("Finished Plotting")
# Out:
#     <script type="text/javascript">
#
#       (function(global) {
#         function now() {
#           return new Date();
#         }
#
#         if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#           window._bokeh_onload_callbacks = [];
#         }
#
#         function run_callbacks() {
#           window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#           delete window._bokeh_onload_callbacks
#           console.info("Bokeh: all callbacks have finished");
#         }
#
#         function load_libs(js_urls, callback) {
#           window._bokeh_onload_callbacks.push(callback);
#           if (window._bokeh_is_loading > 0) {
#             console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#             return null;
#           }
#           if (js_urls == null || js_urls.length === 0) {
#             run_callbacks();
#             return null;
#           }
#           console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#           window._bokeh_is_loading = js_urls.length;
#           for (var i = 0; i < js_urls.length; i++) {
#             var url = js_urls[i];
#             var s = document.createElement('script');
#             s.src = url;
#             s.async = false;
#             s.onreadystatechange = s.onload = function() {
#               window._bokeh_is_loading--;
#               if (window._bokeh_is_loading === 0) {
#                 console.log("Bokeh: all BokehJS libraries loaded");
#                 run_callbacks()
#               }
#             };
#             s.onerror = function() {
#               console.warn("failed to load library " + url);
#             };
#             console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#             document.getElementsByTagName("head")[0].appendChild(s);
#           }
#         };var js_urls = ['https://cdn.pydata.org/bokeh/release/bokeh-0.11.0.min.js', 'https://cdn.pydata.org/bokeh/release/bokeh-widgets-0.11.0.min.js', 'https://cdn.pydata.org/bokeh/release/bokeh-compiler-0.11.0.min.js'];
#
#         var inline_js = [
#           function(Bokeh) {
#             Bokeh.set_log_level("info");
#           },
#           function(Bokeh) {
#             console.log("Bokeh: injecting CSS: https://cdn.pydata.org/bokeh/release/bokeh-0.11.0.min.css");
#             Bokeh.embed.inject_css("https://cdn.pydata.org/bokeh/release/bokeh-0.11.0.min.css");
#             console.log("Bokeh: injecting CSS: https://cdn.pydata.org/bokeh/release/bokeh-widgets-0.11.0.min.css");
#             Bokeh.embed.inject_css("https://cdn.pydata.org/bokeh/release/bokeh-widgets-0.11.0.min.css");
#           }
#         ];
#
#         function run_inline_js() {
#           for (var i = 0; i < inline_js.length; i++) {
#             inline_js[i](window.Bokeh);
#           }
#         }
#
#         if (window._bokeh_is_loading === 0) {
#           console.log("Bokeh: BokehJS loaded, going straight to plotting");
#           run_inline_js();
#         } else {
#           load_libs(js_urls, function() {
#             console.log("Bokeh: BokehJS plotting callback run at", now());
#             run_inline_js();
#           });
#         }
#       }(this));
#     </script>
#     <div>
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span>BokehJS successfully loaded.</span>
#     </div>
# Finished Created Figure
# Plotting
#     <div class="plotdiv" id="58d72080-129d-493a-a438-5004876f8dab"></div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("58d72080-129d-493a-a438-5004876f8dab");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '58d72080-129d-493a-a438-5004876f8dab' but no matching script tag was found. ")
#       return false;
#     }var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"dff3e6c4-9f3e-443a-a188-bd97301c40bf": {"version": "0.11.0", "roots": {"root_ids": ["f7c6ece0-2b64-4b68-9cf4-2e6ad4ad925f", "a0dac9d3-23bd-4ced-bee2-91593db44ca8"], "references": [{"attributes": {"x_range": {"type": "DataRange1d", "id": "30070585-a3f8-4358-a466-a17942cd768c"}, "title": "Middle East tweets (doc2vec)", "y_range": {"type": "DataRange1d", "id": "51063db3-54a9-44e7-bcf3-8b1117da96c9"}, "min_border": 1, "renderers": [{"type": "BoxAnnotation", "id": "1f7e106e-6425-4c99-9008-0280f6c6e4a1"}, {"type": "GlyphRenderer", "id": "41c8daba-da3a-41b6-856b-47be7e426b67"}], "plot_width": 1000, "plot_height": 800, "tool_events": {"type": "ToolEvents", "id": "0ad5eca0-62cf-4091-a1bc-7c2b75d674d9"}, "tools": [{"type": "PanTool", "id": "7b03c162-3b3c-4247-b9c3-3fa9c6ab7f03"}, {"type": "WheelZoomTool", "id": "a8d285ad-fd73-496c-b60c-3ad5ec119b0d"}, {"type": "BoxZoomTool", "id": "9bf31d90-3328-4fb9-b21a-fa689c084555"}, {"type": "ResetTool", "id": "97234ee0-1e21-410d-93d4-7e767dd5136f"}, {"type": "HoverTool", "id": "34f3fbe4-15e1-47c3-abab-0ef0c4ebeb00"}, {"type": "PreviewSaveTool", "id": "afbdaae0-74ae-4bb0-acda-b04187c1e11a"}]}, "type": "Plot", "id": "f7c6ece0-2b64-4b68-9cf4-2e6ad4ad925f", "subtype": "Figure"}, {"attributes": {"callback": null}, "type": "DataRange1d", "id": "9370a0a8-4622-44d2-93e8-fd87ae31d93a"}, {"attributes": {"plot": {"subtype": "Figure", "type": "Plot", "id": "a0dac9d3-23bd-4ced-bee2-91593db44ca8"}}, "type": "WheelZoomTool", "id": "bdb012a0-037a-47f0-9789-e513c6a1bf15"}, {"attributes": {}, "type": "ToolEvents", "id": "0ad5eca0-62cf-4091-a1bc-7c2b75d674d9"}, {"attributes": {"plot": {"subtype": "Figure", "type": "Plot", "id": "f7c6ece0-2b64-4b68-9cf4-2e6ad4ad925f"}}, "type": "PreviewSaveTool", "id": "afbdaae0-74ae-4bb0-acda-b04187c1e11a"}, {"attributes": {"plot": {"subtype": "Figure", "type": "Plot", "id": "f7c6ece0-2b64-4b68-9cf4-2e6ad4ad925f"}}, "type": "PanTool", "id": "7b03c162-3b3c-4247-b9c3-3fa9c6ab7f03"}, {"attributes": {"line_color": {"value": "#1f77b4"}, "x": {"field": "x"}, "fill_color": {"value": "#1f77b4"}, "y": {"field": "y"}}, "type": "Circle", "id": "5ae8d22f-082e-4edf-8887-1e95daf260ff"}, {"attributes": {"line_color": {"value": "#1f77b4"}, "line_alpha": {"value": 0.1}, "fill_color": {"value": "#1f77b4"}, "fill_alpha": {"value": 0.1}, "y": {"field": "y"}, "x": {"field": "x"}}, "type": "Circle", "id": "f5053cc9-8715-4b14-a910-99897587dc73"}, {"attributes": {"line_color": {"value": "black"}, "line_alpha": {"value": 1.0}, "render_mode": "css", "bottom_units": "screen", "level": "overlay", "top_units": "screen", "fill_alpha": {"value": 0.5}, "plot": null, "left_units": "screen", "line_dash": [4, 4], "line_width": {"value": 2}, "right_units": "screen", "fill_color": {"value": "lightgrey"}}, "type": "BoxAnnotation", "id": "6397df09-7173-4005-b811-a06243a41287"}, {"attributes": {"x_range": {"type": "DataRange1d", "id": "3fe6a380-6100-451b-90d6-034596b0ce0c"}, "title": "Middle East tweets (doc2vec)", "y_range": {"type": "DataRange1d", "id": "9370a0a8-4622-44d2-93e8-fd87ae31d93a"}, "min_border": 1, "renderers": [{"type": "BoxAnnotation", "id": "6397df09-7173-4005-b811-a06243a41287"}, {"type": "GlyphRenderer", "id": "57a5ead2-7af9-4407-90bb-eb0f38642765"}], "plot_width": 1000, "plot_height": 800, "tool_events": {"type": "ToolEvents", "id": "c6f7c53f-86d6-4553-8c30-7e9b6d45a125"}, "tools": [{"type": "PanTool", "id": "4744b95e-9486-46b5-9a51-3003c02640ae"}, {"type": "WheelZoomTool", "id": "bdb012a0-037a-47f0-9789-e513c6a1bf15"}, {"type": "BoxZoomTool", "id": "cc7bba40-c430-4b4d-bd5c-a517729404b8"}, {"type": "ResetTool", "id": "6fba4c0e-bd0d-4109-b402-e8063d52e378"}, {"type": "HoverTool", "id": "d136fcb9-1d23-485c-92e2-af66a771e42b"}, {"type": "PreviewSaveTool", "id": "738fb6fe-9154-4bdc-9a3c-07f0c1a45557"}]}, "type": "Plot", "id": "a0dac9d3-23bd-4ced-bee2-91593db44ca8", "subtype": "Figure"}, {"attributes": {"callback": null}, "type": "DataRange1d", "id": "51063db3-54a9-44e7-bcf3-8b ...
# Finished Plotting

# %%
from sklearn.manifold import MDS
rand_vecs = w2v_norm[np.random.choice(w2v_norm.shape[0], 10000, replace=False),:]
MDS_model = MDS(n_components=2, n_jobs=2,random_state=0)
MDS = MDS_model.fit_transform(rand_vecs)
print("Finished model Fitting with MDS")
# Out:
# Finished model Fitting with MDS

# %%
output_notebook()
plot_d2v = bp.figure(plot_width=1000, plot_height=800, title="Wiki Dump (word2vec Yanshuai)",
    tools="pan,wheel_zoom,box_zoom,reset,hover,previewsave",
    x_axis_type=None, y_axis_type=None, min_border=1)
print("Finished Created Figure")
plot_d2v.scatter(x=MDS[:,0], y=MDS[:,1],
                    source=bp.ColumnDataSource({
                        "tweet": bag_of_words[:10000],
                    }))
print("Plotting")
hover = plot_d2v.select(dict(type=HoverTool))
hover.tooltips={"word": "@tweet "}
show(plot_d2v)
print("Finished Plotting")
# Out:
#     <script type="text/javascript">
#
#       (function(global) {
#         function now() {
#           return new Date();
#         }
#
#         if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#           window._bokeh_onload_callbacks = [];
#         }
#
#         function run_callbacks() {
#           window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#           delete window._bokeh_onload_callbacks
#           console.info("Bokeh: all callbacks have finished");
#         }
#
#         function load_libs(js_urls, callback) {
#           window._bokeh_onload_callbacks.push(callback);
#           if (window._bokeh_is_loading > 0) {
#             console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#             return null;
#           }
#           if (js_urls == null || js_urls.length === 0) {
#             run_callbacks();
#             return null;
#           }
#           console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#           window._bokeh_is_loading = js_urls.length;
#           for (var i = 0; i < js_urls.length; i++) {
#             var url = js_urls[i];
#             var s = document.createElement('script');
#             s.src = url;
#             s.async = false;
#             s.onreadystatechange = s.onload = function() {
#               window._bokeh_is_loading--;
#               if (window._bokeh_is_loading === 0) {
#                 console.log("Bokeh: all BokehJS libraries loaded");
#                 run_callbacks()
#               }
#             };
#             s.onerror = function() {
#               console.warn("failed to load library " + url);
#             };
#             console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#             document.getElementsByTagName("head")[0].appendChild(s);
#           }
#         };var js_urls = ['https://cdn.pydata.org/bokeh/release/bokeh-0.11.0.min.js', 'https://cdn.pydata.org/bokeh/release/bokeh-widgets-0.11.0.min.js', 'https://cdn.pydata.org/bokeh/release/bokeh-compiler-0.11.0.min.js'];
#
#         var inline_js = [
#           function(Bokeh) {
#             Bokeh.set_log_level("info");
#           },
#           function(Bokeh) {
#             console.log("Bokeh: injecting CSS: https://cdn.pydata.org/bokeh/release/bokeh-0.11.0.min.css");
#             Bokeh.embed.inject_css("https://cdn.pydata.org/bokeh/release/bokeh-0.11.0.min.css");
#             console.log("Bokeh: injecting CSS: https://cdn.pydata.org/bokeh/release/bokeh-widgets-0.11.0.min.css");
#             Bokeh.embed.inject_css("https://cdn.pydata.org/bokeh/release/bokeh-widgets-0.11.0.min.css");
#           }
#         ];
#
#         function run_inline_js() {
#           for (var i = 0; i < inline_js.length; i++) {
#             inline_js[i](window.Bokeh);
#           }
#         }
#
#         if (window._bokeh_is_loading === 0) {
#           console.log("Bokeh: BokehJS loaded, going straight to plotting");
#           run_inline_js();
#         } else {
#           load_libs(js_urls, function() {
#             console.log("Bokeh: BokehJS plotting callback run at", now());
#             run_inline_js();
#           });
#         }
#       }(this));
#     </script>
#     <div>
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span>BokehJS successfully loaded.</span>
#     </div>
# Finished Created Figure
# Plotting
#     <div class="plotdiv" id="ea5e84ff-5178-4d74-b348-853e705fed54"></div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("ea5e84ff-5178-4d74-b348-853e705fed54");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'ea5e84ff-5178-4d74-b348-853e705fed54' but no matching script tag was found. ")
#       return false;
#     }var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"40e800ff-6f9a-4492-a62b-1f22cb706c8d": {"version": "0.11.0", "roots": {"root_ids": ["f7c6ece0-2b64-4b68-9cf4-2e6ad4ad925f", "a0dac9d3-23bd-4ced-bee2-91593db44ca8", "e6590bb0-f3c8-4b5e-b12d-81f013045aca", "2cebe737-8f91-4286-90bc-220940bcb97f"], "references": [{"attributes": {"callback": null}, "type": "DataRange1d", "id": "0b92c997-43bd-4bb2-bdf1-9d43063f2847"}, {"attributes": {"x_range": {"type": "DataRange1d", "id": "30070585-a3f8-4358-a466-a17942cd768c"}, "title": "Middle East tweets (doc2vec)", "y_range": {"type": "DataRange1d", "id": "51063db3-54a9-44e7-bcf3-8b1117da96c9"}, "min_border": 1, "renderers": [{"type": "BoxAnnotation", "id": "1f7e106e-6425-4c99-9008-0280f6c6e4a1"}, {"type": "GlyphRenderer", "id": "41c8daba-da3a-41b6-856b-47be7e426b67"}], "plot_width": 1000, "plot_height": 800, "tool_events": {"type": "ToolEvents", "id": "0ad5eca0-62cf-4091-a1bc-7c2b75d674d9"}, "tools": [{"type": "PanTool", "id": "7b03c162-3b3c-4247-b9c3-3fa9c6ab7f03"}, {"type": "WheelZoomTool", "id": "a8d285ad-fd73-496c-b60c-3ad5ec119b0d"}, {"type": "BoxZoomTool", "id": "9bf31d90-3328-4fb9-b21a-fa689c084555"}, {"type": "ResetTool", "id": "97234ee0-1e21-410d-93d4-7e767dd5136f"}, {"type": "HoverTool", "id": "34f3fbe4-15e1-47c3-abab-0ef0c4ebeb00"}, {"type": "PreviewSaveTool", "id": "afbdaae0-74ae-4bb0-acda-b04187c1e11a"}]}, "type": "Plot", "id": "f7c6ece0-2b64-4b68-9cf4-2e6ad4ad925f", "subtype": "Figure"}, {"attributes": {"callback": null, "column_names": ["tweet", "y", "x"], "data": {"y": [-6.57924570130192, 3.775249376675212, 1.424037401608256, -2.9627716641402615, 2.46073426935857, 0.5095176218768249, -6.134912100016898, -0.6081773220572083, -0.6284754616563947, -6.726735786566023, -1.0296931695164624, 1.0921219690091384, 7.567663352617242, -7.426547900171541, 3.325265370657355, -6.218830669430391, 0.825901366630367, 1.8567417415506433, -5.466408094309724, -2.2542970204689916, -2.6698865353366497, -2.7272161736351714, 7.092683615916517, 5.659756943957494, 7.617266693376731, -2.1674088062976753, 1.834070260813878, -4.1581155090571675, 8.401899750401986, 7.478943185110389, 3.2726594752601463, -4.228541096415015, 7.864905734992341, -2.5482557845104923, 8.34224294573665, 2.1579095107568778, 1.1916701652095312, -5.876853057622822, 1.0508705784426078, 1.1707219149251746, 4.413356555304278, -6.901291831667134, 1.6231621035386676, 1.6423532587712126, -5.690279229875535, 3.6433802189253033, 0.5039193511361914, 5.6516104089897885, 5.1044410777433855, 2.057174840834453, -5.100872392687308, -3.9860587855522347, -7.764970662375899, -3.3916687705632493, 2.233853405826856, -6.148070760235404, -2.577754982471539, 0.8526000310203489, -0.49024197097679895, 6.035427554630989, -4.186402741287647, -4.660364502549182, -7.490231186164147, -5.905308729755713, 2.1254329966967913, -0.8884813983271052, -3.2100849985289117, 9.190809768269158, -6.195048789409851, 0.7071882569288114, 8.153142592923588, -2.0830670182999422, 4.454916674280274, 2.3439735055357502, 2.832626181619365, 4.1005105481702016, -4.353310347775436, -3.165142974755046, 0.46433696770347677, 6.446460268649587, -6.194437890380141, 0.7021220725462198, 2.043250519089004, -0.07934875595012807, 1.9305544678457673, 8.60244933600896, -6.051093137081677, -3.698855639932003, -1.6165771362936487, 1.3501570068606645, 6.106641013083112, 4.162991558296271, 7.747637659211876, -2.701174934162957, 2.5592490652930278, -4.199933389800042, 0.36289257398773433, 3.0664126057723147, 3.0545386169754933, 7.018397542370152, -5.090696147512212, 3.850568373351961, 3.0569816291499783, -3.853351409425455, -3.271789788221013, 3.7928360906814658, -0.14124152500803228, 2.586874539005622, 0.4451362835415641, -1.181883692986958, 1.2404613162316318, 5.811648126152346, -3.1210795083553444, 3.8857622540527967, -4.09245777530947, -2.071080146463222, 2.854965772120252, -2.4777445502199247, 3.6809372068100403, 3.1519398467538045, 2.4420219372102863, 5.818881684189425, 1.2539244049062424, 7.0569055851321965, -5.89200 ...
# Finished Plotting

# %%
norm2 = normalize(x[:,np.newaxis], axis=0).ravel()
